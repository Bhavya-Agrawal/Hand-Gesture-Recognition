#   inflating: Custom Dataset/4/4_61.jpg
#   inflating: Custom Dataset/4/4_62.jpg
#   inflating: Custom Dataset/4/4_63.jpg
#   inflating: Custom Dataset/4/4_64.jpg
#   inflating: Custom Dataset/4/4_65.jpg
#   inflating: Custom Dataset/4/4_66.jpg
#   inflating: Custom Dataset/4/4_67.jpg
#   inflating: Custom Dataset/4/4_68.jpg
#   inflating: Custom Dataset/4/4_69.jpg
#   inflating: Custom Dataset/4/4_70.jpg
#   inflating: Custom Dataset/4/4_71.jpg
#   inflating: Custom Dataset/4/4_72.jpg
#   inflating: Custom Dataset/4/4_73.jpg
#   inflating: Custom Dataset/4/4_74.jpg
#   inflating: Custom Dataset/4/4_75.jpg
#   inflating: Custom Dataset/4/4_76.jpg
#   inflating: Custom Dataset/4/4_77.jpg
#   inflating: Custom Dataset/4/4_78.jpg
#   inflating: Custom Dataset/4/4_79.jpg
#   inflating: Custom Dataset/4/4_80.jpg
#   inflating: Custom Dataset/4/4_81.jpg
#   inflating: Custom Dataset/4/4_82.jpg
#   inflating: Custom Dataset/4/4_83.jpg
#   inflating: Custom Dataset/4/4_84.jpg
#   inflating: Custom Dataset/4/4_85.jpg
#   inflating: Custom Dataset/4/4_86.jpg
#   inflating: Custom Dataset/4/4_87.jpg
#   inflating: Custom Dataset/4/4_88.jpg
#   inflating: Custom Dataset/4/4_89.jpg
#   inflating: Custom Dataset/4/4_90.jpg
#   inflating: Custom Dataset/4/4_91.jpg
#   inflating: Custom Dataset/4/4_92.jpg
#   inflating: Custom Dataset/4/4_93.jpg
#   inflating: Custom Dataset/4/4_94.jpg
#   inflating: Custom Dataset/4/4_95.jpg
#   inflating: Custom Dataset/4/4_96.jpg
#   inflating: Custom Dataset/4/4_97.jpg
#   inflating: Custom Dataset/4/4_98.jpg
#   inflating: Custom Dataset/4/4_99.jpg

# %%
custom_dataset = "/content/Custom Dataset"

# %%
glob.glob(custom_dataset + '/*')
# Out:
# ['/content/Custom Dataset/4',
#  '/content/Custom Dataset/1',
#  '/content/Custom Dataset/2',
#  '/content/Custom Dataset/3']

# %%
total_images = len(glob.glob(custom_dataset + '/*/*'))
total_images

# total images = 942
# Out:
# 942

# %% [markdown]
# ## Train-Test Split

# %%
pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders

# %%
splitfolders.ratio(input = custom_dataset,
                  output = 'custom_images_1to4',
                  ratio=(0.75, 0.15, 0.1))
# Out:
# Copying files: 942 files [00:00, 3256.07 files/s]

# %% [markdown]
# ## Assign the class-names

# %%
labels = []
images = []
for i in (glob.glob('./custom_images_1to4/*/*/*')):
    images.append(i)
    label = i.split('_')[2][-1]
    labels.append(label)

# %%
images[720], labels[720]
# Out:
# ('./custom_images_1to4/val/4/4_116.jpg', '4')

# %%
class_names = ['1', '2', '3', '4']

# %% [markdown]
# ## Visualize Random Images

# %%
import random
import cv2
import numpy as np
import matplotlib.image as mpimg

# %%
random_sample = random.sample(images, 2)

plt.figure(figsize=(10,7))

img1 = mpimg.imread(random_sample[0])
plt.subplot(1, 2, 1)
plt.imshow(img1)
plt.title(random_sample[0].split('_')[2][-1])

img2 = mpimg.imread(random_sample[1])
plt.subplot(1, 2, 2)
plt.imshow(img2)
plt.title(random_sample[1].split('_')[2][-1])
# Out:
# Text(0.5, 1.0, '1')

# %%
images_tensor = tf.constant(images)

# %% [markdown]
# ## Preprocessing the images

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.layers import Dense, Conv2D, Flatten

# %%
# Assign the variables according to train, val and test sets

training_data = './custom_images_1to4/train/'
validation_data = './custom_images_1to4/val/'
test_data = './custom_images_1to4/test/'

# %%
# Set the random Seed

tf.random.set_seed(42)

# Preprocess data (get all of the pixel values between 0 & 1, also called scaling/normalization)
train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Import data from directories and turn it into batches

training_images = train_datagen.flow_from_directory(directory= training_data,
                                                   target_size= (224,224),
                                                   batch_size = 16,
                                                   class_mode="categorical")

validation_images = test_datagen.flow_from_directory(directory= validation_data,
                                                   target_size= (224,224),
                                                   batch_size = 16,
                                                   class_mode="categorical")
# Out:
# Found 705 images belonging to 4 classes.
# Found 140 images belonging to 4 classes.

# %% [markdown]
# ## **Custom Model**

# %% [markdown]
# ### **Creating custom Model**

# %%
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Activation
from tensorflow.keras import Sequential

# %%
model_2 = Sequential()

model_2.add(Conv2D(150, (3, 3), input_shape=( 224, 224, 3)))
model_2.add(Activation('relu'))
model_2.add(MaxPooling2D(pool_size=(2,2)))

model_2.add(Conv2D(200, (3, 3)))
model_2.add(Activation('relu'))
model_2.add(MaxPooling2D(pool_size=(2, 2)))

model_2.add(Conv2D(215, (3, 3)))
model_2.add(Activation('relu'))
model_2.add(MaxPooling2D(pool_size=(2, 2)))


model_2.add(Conv2D(190, (3, 3)))
model_2.add(Activation('relu'))
model_2.add(MaxPooling2D(pool_size=(2, 2)))

model_2.add(Flatten()) 
model_2.add(Dense(300))
model_2.add(Activation('relu'))

model_2.add(Dense(4))
model_2.add(Activation('softmax'))

model_2.compile(loss=tf.keras.losses.categorical_crossentropy,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

# %%
model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 150)     4200
#
#  activation (Activation)     (None, 222, 222, 150)     0
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 150)    0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 200)     270200
#
#  activation_1 (Activation)   (None, 109, 109, 200)     0
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 200)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 215)       387215
#
#  activation_2 (Activation)   (None, 52, 52, 215)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 215)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 190)       367840
#
#  activation_3 (Activation)   (None, 24, 24, 190)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 190)      0
#  2D)
#
#  flatten (Flatten)           (None, 27360)             0
#
#  dense (Dense)               (None, 300)               8208300
#
#  activation_4 (Activation)   (None, 300)               0
#
#  dense_1 (Dense)             (None, 4)                 1204
#
#  activation_5 (Activation)   (None, 4)                 0
#
# =================================================================
# Total params: 9,238,959
# Trainable params: 9,238,959
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **CallBack:** :
# For comparision on Tensorboard

# %%
import datetime

def create_tensorboard_callback(dir_name, experiment_name):
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)
  print(f"Saving TensorBoard log files to: {log_dir}")
  return tensorboard_callback

# %% [markdown]
# ### **Fitting the Custom Model**

# %%
history_2 = model_2.fit(training_images,
                        epochs=15,
                        validation_data=validation_images,
                        callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub",
                                                                                     experiment_name="Custom Model")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/Custom Model/20221017-042012
# Epoch 1/15
# 45/45 [==============================] - 18s 177ms/step - loss: 1.1580 - accuracy: 0.4539 - val_loss: 0.1547 - val_accuracy: 0.9571
# Epoch 2/15
# 45/45 [==============================] - 6s 137ms/step - loss: 0.2024 - accuracy: 0.9376 - val_loss: 0.1024 - val_accuracy: 0.9500
# Epoch 3/15
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0946 - accuracy: 0.9773 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 4/15
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0133 - accuracy: 0.9972 - val_loss: 0.1121 - val_accuracy: 0.9643
# Epoch 5/15
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0163 - accuracy: 0.9957 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 6/15
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0044 - accuracy: 0.9972 - val_loss: 0.0099 - val_accuracy: 0.9929
# Epoch 7/15
# 45/45 [==============================] - 7s 156ms/step - loss: 3.6352e-04 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9929
# Epoch 8/15
# 45/45 [==============================] - 8s 173ms/step - loss: 5.9139e-05 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9929
# Epoch 9/15
# 45/45 [==============================] - 6s 138ms/step - loss: 2.2385e-05 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9929
# Epoch 10/15
# 45/45 [==============================] - 6s 140ms/step - loss: 1.4020e-05 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9929
# Epoch 11/15
# 45/45 [==============================] - 6s 140ms/step - loss: 9.1627e-06 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9929
# Epoch 12/15
# 45/45 [==============================] - 6s 139ms/step - loss: 7.1251e-06 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 0.9929
# Epoch 13/15
# 45/45 [==============================] - 6s 141ms/step - loss: 5.5096e-06 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9929
# Epoch 14/15
# 45/45 [==============================] - 6s 140ms/step - loss: 4.4512e-06 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9929
# Epoch 15/15
# 45/45 [==============================] - 6s 141ms/step - loss: 3.7176e-06 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9929

# %% [markdown]
# ### **Predicting the custom model**

# %% [markdown]
# #### **Load and preprocess the new images**

# %%
def prepare_test_image(image):
    # Step 1 : Read the image
    test_img = tf.io.read_file(image)

    #Step 2: Decode the image in tensor
    test_img = tf.image.decode_image(test_img)

    #Step 3: Resize the image:
    test_img = tf.image.resize(test_img, size = [224, 224])

    # Step 4: Rescale the image:
    test_img = test_img/255.

    #Step 5: Convert into 4D
    test_img = tf.expand_dims(test_img, axis=0)
    
    return test_img

# %% [markdown]
# #### **Plot the predicted result**

# %%
def plot_predicted_output (test_image, model = model_2, class_names = class_names):
    # Step 1 : Load and preprocess the test image
    testimage = prepare_test_image(test_image)

    # Step 2 : Predict
    prediction_output = model.predict(testimage)
    print(prediction_output)
    print(type(prediction_output))

    # Step 3 : Find out the predicted class
    if len(prediction_output[0]) > 1:
        pred_class = class_names[tf.argmax(prediction_output[0])]
        print("Class : ", pred_class)
    else:
        pred_class = class_names[int(tf.round(prediction_output[0]))]
        print("Class : ",pred_class)

    # Step 4 : Visualize the test image + PREDICTED CLASS
    plt.figure()
    plt.imshow(tf.squeeze(testimage))
    plt.title(f" Predicted Class : {pred_class}")
    plt.axis = False

# %% [markdown]
# #### **Testing a Single Image from Test Set**

# %%
# prepare_test_image(r'D:\HAND RECOGNITION SYSTEMS\Code\Custom Dataset\3/3_18.jpg')
plot_predicted_output('/content/custom_images_1to4/test/2/2_136.jpg')
# Out:
# 1/1 [==============================] - 0s 32ms/step
# [[4.4594159e-07 9.9999952e-01 1.3881927e-22 1.4774408e-12]]
# <class 'numpy.ndarray'>
# Class :  2

# %% [markdown]
# #### **Evaluating on all Test Images**

# %%
model_2.evaluate(test_images)
# Out:
# 7/7 [==============================] - 1s 156ms/step - loss: 5.0928e-05 - accuracy: 1.0000
# [5.092757419333793e-05, 1.0]

# %% [markdown]
# #### **Plotting the accuracy and Loss Curves**

# %%
history_2.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import pandas as pd

# %%
df = pd.DataFrame(history_2.history)
df.plot(figsize=(10, 7))

# %% [markdown]
# ## **Custom Model with Augmented dataset**

# %% [markdown]
# ### **Data Augmentation**

# %%
# Set the random Seed

tf.random.set_seed(42)


#Data Augmentation
train_datagen_augmented = ImageDataGenerator(rescale=1./255,
                                   rotation_range= 0.4,
                                   zoom_range=0.3,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='constant')


test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Import data from directories and turn it into batches

augmented_training_images = train_datagen_augmented.flow_from_directory(directory = training_data,
                                                                        target_size = (224,224),
                                                                        batch_size = 16,
                                                                        shuffle=False)

augmented_validation_images = train_datagen_augmented.flow_from_directory(directory=validation_data,
                                                     target_size=(224,224),
                                                     batch_size=16,
                                                     shuffle=False)

test_images = test_datagen.flow_from_directory(directory=test_data,
                                              target_size = (224,224),
                                               batch_size = 16
                                              )
# Out:
# Found 705 images belonging to 4 classes.
# Found 140 images belonging to 4 classes.
# Found 97 images belonging to 4 classes.

# %%
# original_images, original_labels = training_images.next()

augmented_images, augmented_labels = augmented_training_images.next()

# %% [markdown]
# ### **Visualizing Augmented Images**

# %%
import random
random_number = random.randint(0,15)
print(f"Random image number : {random_number}")

#Visualize Augmented Image
plt.figure()
plt.imshow(augmented_images[random_number])
plt.title('Augmented Image')
# plt.axis(False)
# Out:
# Random image number : 2
# Text(0.5, 1.0, 'Augmented Image')

# %% [markdown]
# ### **Defining the Custom Model - Same as above model (model_2)**

# %%
model_2_aug = Sequential()

model_2_aug.add(Conv2D(150, (3, 3), input_shape=( 224, 224, 3)))
model_2_aug.add(Activation('relu'))
model_2_aug.add(MaxPooling2D(pool_size=(2,2)))

model_2_aug.add(Conv2D(200, (3, 3)))
model_2_aug.add(Activation('relu'))
model_2_aug.add(MaxPooling2D(pool_size=(2, 2)))

model_2_aug.add(Conv2D(215, (3, 3)))
model_2_aug.add(Activation('relu'))
model_2_aug.add(MaxPooling2D(pool_size=(2, 2)))


model_2_aug.add(Conv2D(190, (3, 3)))
model_2_aug.add(Activation('relu'))
model_2_aug.add(MaxPooling2D(pool_size=(2, 2)))

model_2_aug.add(Flatten()) 
model_2_aug.add(Dense(300))
model_2_aug.add(Activation('relu'))

model_2_aug.add(Dense(4))
model_2_aug.add(Activation('softmax'))

model_2_aug.compile(loss=tf.keras.losses.categorical_crossentropy,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

# %% [markdown]
# ###  **<font color='red'> Using Data augmentation, accuracy drops.**

# %%
history_2_aug = model_2_aug.fit(augmented_training_images,
                                epochs=15,
                                validation_data=augmented_validation_images)
# Out:
# Epoch 1/15
# 45/45 [==============================] - 14s 304ms/step - loss: 1.4875 - accuracy: 0.1376 - val_loss: 1.3859 - val_accuracy: 0.3000
# Epoch 2/15
# 45/45 [==============================] - 13s 292ms/step - loss: 1.3867 - accuracy: 0.1830 - val_loss: 1.3856 - val_accuracy: 0.3000
# Epoch 3/15
# 45/45 [==============================] - 13s 290ms/step - loss: 1.3864 - accuracy: 0.2993 - val_loss: 1.3849 - val_accuracy: 0.3000
# Epoch 4/15
# 45/45 [==============================] - 13s 293ms/step - loss: 1.3862 - accuracy: 0.2993 - val_loss: 1.3845 - val_accuracy: 0.3000
# Epoch 5/15
# 45/45 [==============================] - 14s 303ms/step - loss: 1.3853 - accuracy: 0.2993 - val_loss: 1.3840 - val_accuracy: 0.3000
# Epoch 6/15
# 45/45 [==============================] - 14s 321ms/step - loss: 1.3845 - accuracy: 0.2993 - val_loss: 1.3838 - val_accuracy: 0.3000
# Epoch 7/15
# 45/45 [==============================] - 16s 355ms/step - loss: 1.3847 - accuracy: 0.2993 - val_loss: 1.3832 - val_accuracy: 0.3000
# Epoch 8/15
# 45/45 [==============================] - 16s 350ms/step - loss: 1.3846 - accuracy: 0.2993 - val_loss: 1.3828 - val_accuracy: 0.3000
# Epoch 9/15
# 45/45 [==============================] - 13s 293ms/step - loss: 1.3840 - accuracy: 0.2993 - val_loss: 1.3828 - val_accuracy: 0.3000
# Epoch 10/15
# 45/45 [==============================] - 13s 293ms/step - loss: 1.3836 - accuracy: 0.2993 - val_loss: 1.3823 - val_accuracy: 0.3000
# Epoch 11/15
# 45/45 [==============================] - 13s 292ms/step - loss: 1.3837 - accuracy: 0.2993 - val_loss: 1.3820 - val_accuracy: 0.3000
# Epoch 12/15
# 45/45 [==============================] - 14s 315ms/step - loss: 1.3836 - accuracy: 0.2993 - val_loss: 1.3819 - val_accuracy: 0.3000
# Epoch 13/15
# 45/45 [==============================] - 13s 291ms/step - loss: 1.3830 - accuracy: 0.2993 - val_loss: 1.3820 - val_accuracy: 0.3000
# Epoch 14/15
# 45/45 [==============================] - 14s 306ms/step - loss: 1.3835 - accuracy: 0.2993 - val_loss: 1.3813 - val_accuracy: 0.3000
# Epoch 15/15
# 45/45 [==============================] - 13s 292ms/step - loss: 1.3824 - accuracy: 0.2993 - val_loss: 1.3814 - val_accuracy: 0.3000

# %% [markdown]
# ### **Evaluating on all Test Images**

# %%
model_2_aug.evaluate(test_images)
# Out:
# 7/7 [==============================] - 1s 83ms/step - loss: 1.3812 - accuracy: 0.2990
# [1.381217360496521, 0.2989690601825714]

# %% [markdown]
# ### **Plotting the accuracy and Loss Curves**

# %%
import pandas as pd
t = pd.DataFrame(history_2_aug.history)

# %%
t.plot()

# %% [markdown]
# # **Creating models using TensorFlow Hub**

# %% [markdown]
# ## **Callbacks**
#
# Callbacks are extra functionality you can add to your models to be performed during or after training. Some of the most popular callbacks:
#
# * Tracking experiments with the TensorBoard callback
# * Model checkpoint with the ModelCheckpoint callback
# * Stopping a model from training (before it trains too long and overfits) with the EarlyStopping callback

# %%
pip install --upgrade tensorflow-hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.7/dist-packages (0.12.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-hub) (1.21.6)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-hub) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorflow-hub) (1.15.0)

# %%
import tensorflow_hub as hub

# %% [markdown]
# ### **Get links for Resnet & Efficient Models from Tensorhub official Website**

# %%
resnet_url = "https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4"

efficientnet_url = "https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1"

# %% [markdown]
# ### **Defining the model  --> Resnet Model + LAst layer( classes =4)**

# %%
def create_model(model_url, num_classes=10):
    feature_extractor_layer = hub.KerasLayer(model_url,
                                           trainable=False, # freeze the already learned patterns
                                           name="feature_extraction_lyaer",
                                           input_shape=(224,224)+(3,)) 
    model = tf.keras.Sequential([
    feature_extractor_layer,
    tf.keras.layers.Dense(num_classes, activation="softmax", name="output_layer")
  ])
    
    return model

# %% [markdown]
# ## **Resnet Model**

# %% [markdown]
# ### **Creating the Model**

# %%
resnet_model = create_model(resnet_url,
                            num_classes=training_images.num_classes)

# %%
resnet_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_lyaer (K  (None, 2048)             23564800
#  erasLayer)
#
#  output_layer (Dense)        (None, 4)                 8196
#
# =================================================================
# Total params: 23,572,996
# Trainable params: 8,196
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
# Compile the model
resnet_model.compile(loss = 'categorical_crossentropy',
                    optimizer = tf.keras.optimizers.Adam(),
                    metrics = 'accuracy')

# %% [markdown]
# ### **Fitting the Model**

# %%
# Fit the model

resnet_history = resnet_model.fit(training_images,
                                 epochs = 15,
                                 validation_data= validation_images,
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub",
                                                                         experiment_name="resnet50V2"
                                                                         )])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/resnet50V2/20221017-042907
# Epoch 1/15
# 45/45 [==============================] - 22s 194ms/step - loss: 0.6974 - accuracy: 0.7589 - val_loss: 0.2517 - val_accuracy: 0.9714
# Epoch 2/15
# 45/45 [==============================] - 6s 125ms/step - loss: 0.1519 - accuracy: 0.9773 - val_loss: 0.1286 - val_accuracy: 0.9786
# Epoch 3/15
# 45/45 [==============================] - 6s 126ms/step - loss: 0.0818 - accuracy: 0.9915 - val_loss: 0.0894 - val_accuracy: 0.9857
# Epoch 4/15
# 45/45 [==============================] - 5s 118ms/step - loss: 0.0542 - accuracy: 0.9986 - val_loss: 0.0787 - val_accuracy: 0.9857
# Epoch 5/15
# 45/45 [==============================] - 8s 183ms/step - loss: 0.0401 - accuracy: 0.9986 - val_loss: 0.0639 - val_accuracy: 0.9857
# Epoch 6/15
# 45/45 [==============================] - 5s 116ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.0518 - val_accuracy: 0.9857
# Epoch 7/15
# 45/45 [==============================] - 6s 125ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.0477 - val_accuracy: 0.9857
# Epoch 8/15
# 45/45 [==============================] - 5s 115ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9857
# Epoch 9/15
# 45/45 [==============================] - 6s 128ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9857
# Epoch 10/15
# 45/45 [==============================] - 5s 115ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 0.9857
# Epoch 11/15
# 45/45 [==============================] - 5s 115ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9857
# Epoch 12/15
# 45/45 [==============================] - 5s 114ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 0.9857
# Epoch 13/15
# 45/45 [==============================] - 5s 115ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9857
# Epoch 14/15
# 45/45 [==============================] - 7s 153ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9857
# Epoch 15/15
# 45/45 [==============================] - 7s 151ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 0.9857

# %% [markdown]
# ### **Evaluation Curves - Accuracy & Loss Curves**

# %%
def plot_evaluation_curves(history):
    
    loss = resnet_history.history['loss']
    val_loss = resnet_history.history['val_loss']
    
    accuracy = resnet_history.history['accuracy']
    val_accuracy = resnet_history.history['val_accuracy']
    
    epochs = range(len(resnet_history.history["loss"]))
    
    ## Plotting loss curves
#     plt.figure()
    plt.plot(epochs, loss, label = "Training Loss")
    plt.plot(epochs, val_loss, label = "Validation loss")
    plt.title('Loss curves')
    plt.xlabel('Epochs')
    plt.legend()
    
    ## Plotting Accuracy curves
    plt.figure()   
    plt.plot(epochs, accuracy, label = 'Training Accuracy')
    plt.plot(epochs, val_accuracy, label = 'Validation Accuracy')
    plt.title("Accuracy Curves")
    plt.xlabel("Epochs")
    plt.legend()

# %%
plot_evaluation_curves(resnet_history)

# %% [markdown]
# ### **Testing a Single Image from Test set**

# %%
plot_predicted_output('/content/custom_images_1to4/test/3/3_136.jpg', model = resnet_model)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# [[1.6942613e-03 6.7966437e-04 9.8615682e-01 1.1469298e-02]]
# <class 'numpy.ndarray'>
# Class :  3

# %% [markdown]
# ### **Evaluation on all Test Images**

# %%
resnet_model.evaluate(test_images)
# Out:
# 7/7 [==============================] - 1s 125ms/step - loss: 0.0129 - accuracy: 1.0000
# [0.012891309335827827, 1.0]

# %% [markdown]
# ### **Plotting the accuracy and Loss curves**

# %%
df = pd.DataFrame(resnet_history.history)
df.plot(figsize=(10, 7))

# %% [markdown]
# ## **Efficientnet Model**

# %% [markdown]
# ### **Creating the model**

# %%
efficientnet_model = create_model(model_url = efficientnet_url,
                                 num_classes = 4)

# %%
efficientnet_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_lyaer (K  (None, 1280)             4049564
#  erasLayer)
#
#  output_layer (Dense)        (None, 4)                 5124
#
# =================================================================
# Total params: 4,054,688
# Trainable params: 5,124
# Non-trainable params: 4,049,564
# _________________________________________________________________

# %%
# Compile the model

efficientnet_model.compile(loss = 'categorical_crossentropy',
                          optimizer = tf.keras.optimizers.Adam(),
                          metrics = 'accuracy')

# %% [markdown]
# ### **Fitting the Model**

# %%
efficientnet_history = efficientnet_model.fit(training_images,
                                              epochs = 15,
                                              validation_data= validation_images,
                                              callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub",
                                                                                     experiment_name="EfficientNet"
                                                                                     )])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/EfficientNet/20221017-043434
# Epoch 1/15
# 45/45 [==============================] - 13s 208ms/step - loss: 0.5926 - accuracy: 0.9007 - val_loss: 0.2597 - val_accuracy: 0.9786
# Epoch 2/15
# 45/45 [==============================] - 6s 124ms/step - loss: 0.1533 - accuracy: 0.9943 - val_loss: 0.1202 - val_accuracy: 0.9857
# Epoch 3/15
# 45/45 [==============================] - 5s 116ms/step - loss: 0.0824 - accuracy: 0.9972 - val_loss: 0.0758 - val_accuracy: 0.9929
# Epoch 4/15
# 45/45 [==============================] - 6s 137ms/step - loss: 0.0541 - accuracy: 0.9986 - val_loss: 0.0534 - val_accuracy: 0.9929
# Epoch 5/15
# 45/45 [==============================] - 5s 117ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9929
# Epoch 6/15
# 45/45 [==============================] - 6s 126ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 7/15
# 45/45 [==============================] - 7s 158ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 1.0000
# Epoch 8/15
# 45/45 [==============================] - 5s 112ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 9/15
# 45/45 [==============================] - 5s 114ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 10/15
# 45/45 [==============================] - 5s 113ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 11/15
# 45/45 [==============================] - 5s 112ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 12/15
# 45/45 [==============================] - 5s 121ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 13/15
# 45/45 [==============================] - 5s 114ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 14/15
# 45/45 [==============================] - 5s 114ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 15/15
# 45/45 [==============================] - 7s 162ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000

# %% [markdown]
# ### **Testing a single Image from Test Set**

# %%
plot_predicted_output('/content/custom_images_1to4/test/3/3_136.jpg', model = efficientnet_model)
# Out:
# 1/1 [==============================] - 2s 2s/step
# [[2.7074388e-04 2.0426542e-05 9.9825829e-01 1.4505172e-03]]
# <class 'numpy.ndarray'>
# Class :  3

# %% [markdown]
# ### **Evaluation on all Test Images**

# %%
efficientnet_model.evaluate(test_images)
# Out:
# 7/7 [==============================] - 1s 81ms/step - loss: 0.0086 - accuracy: 1.0000
# [0.008575700223445892, 1.0]

# %% [markdown]
# ### **Plotting the accuracy and Loss curves**

# %%
df = pd.DataFrame(efficientnet_history.history)
df.plot(figsize=(10, 7))

# %% [markdown]
# # **TensorBoard**

# %%
# !tensorboard dev upload --logdir ./tensorflow_hub/ \
  --name "EfficientNetB0 vs. ResNet50V2" \
  --description "Comparing two different TF Hub feature extraction model architectures" \
  --one_shot
# Out:
# ***** TensorBoard Uploader *****
#
# This will upload your TensorBoard logs to https://tensorboard.dev/ from
# the following directory:
#
# ./tensorflow_hub/
#
# This TensorBoard will be visible to everyone. Do not upload sensitive
# data.
#
# Your use of this service is subject to Google's Terms of Service
# <https://policies.google.com/terms> and Privacy Policy
# <https://policies.google.com/privacy>, and TensorBoard.dev's Terms of Service
# <https://tensorboard.dev/policy/terms/>.
#
# This notice will not be shown again while you are logged into the uploader.
# To log out, run `tensorboard dev auth revoke`.
#
# Continue? (yes/NO) yes
#
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=373649185512-8v619h5kft38l4456nm2dj4ubeqsrvh6.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&state=E7gEeyjQU8hjboQLJYFKxyrrk14309&prompt=consent&access_type=offline
# Enter the authorization code: 4/1ARtbsJpsKv9nhVfzDqPO1P9UWYv2t5685PZylfhsnUUPGyqENR7Hh2-CgPk
#
#
# New experiment created. View your TensorBoard at: https://tensorboard.dev/experiment/5jlJCZw7TB25za1rmvCNTw/
#
# [2022-10-17T05:05:08] Started scanning logdir.
# [2022-10-17T05:05:12] Total uploaded: 270 scalars, 0 tensors, 3 binary objects (6.6 MB)
# [2022-10-17T05:05:12] Done scanning logdir.
#
#
# Done. View your TensorBoard at https://tensorboard.dev/experiment/5jlJCZw7TB25za1rmvCNTw/

# %%
# !tensorboard dev list
# Out:
# https://tensorboard.dev/experiment/5jlJCZw7TB25za1rmvCNTw/
# 	Name                 EfficientNetB0 vs. ResNet50V2
# 	Description          Comparing two different TF Hub feature extraction model architectures
# 	Id                   5jlJCZw7TB25za1rmvCNTw
# 	Created              2022-10-17 05:05:08 (26 seconds ago)
# 	Updated              2022-10-17 05:05:12 (22 seconds ago)
# 	Runs                 6
# 	Tags                 5
# 	Scalars              270
# 	Tensor bytes         0
# 	Binary object bytes  6896700
# https://tensorboard.dev/experiment/O0nY4slMQ6WfRxXJK9uGSg/
# 	Name                 EfficientNetB0 vs. ResNet50V2
# 	Description          Comparing two different TF Hub feature extraction model architectures
# 	Id                   O0nY4slMQ6WfRxXJK9uGSg
# 	Created              2022-10-14 06:06:54
# 	Updated              2022-10-14 06:06:56
# 	Runs                 6
# 	Tags                 5
# 	Scalars              120
# 	Tensor bytes         0
# 	Binary object bytes  5983890
# https://tensorboard.dev/experiment/VW1hOtWbTEuRlZryxU8QjA/
# 	Name                 EfficientNetB0 vs. ResNet50V2
# 	Description          Comparing two different TF Hub feature extraction model architectures
# 	Id                   VW1hOtWbTEuRlZryxU8QjA
# 	Created              2022-10-14 05:50:17
# 	Updated              2022-10-14 05:50:19
# 	Runs                 6
# 	Tags                 5
# 	Scalars              120
# 	Tensor bytes         0
# 	Binary object bytes  5983890
# https://tensorboard.dev/experiment/g517zVuqRXu4gIVmrLFRMA/
# 	Name                 EfficientNetB0 vs. ResNet50V2
# 	Description          Comparing two different TF Hub feature extraction model architectures
# 	Id                   g517zVuqRXu4gIVmrLFRMA
# 	Created              2022-10-14 05:40:47
# 	Updated              2022-10-14 05:40:49
# 	Runs                 4
# 	Tags                 5
# 	Scalars              60
# 	Tensor bytes         0
# 	Binary object bytes  5924683
# Total: 4 experiment(s)
